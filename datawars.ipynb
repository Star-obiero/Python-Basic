# %% [markdown]
# Foot ball players analsis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path=r"C:\Users\Administrator\Downloads\archive (2)\fifa_players.csv"
data=pd.read_csv(file_path)
data
# Out:
#                  name                         full_name birth_date  age  \
# 0            L. Messi    Lionel Andrés Messi Cuccittini  6/24/1987   31
# 1          C. Eriksen      Christian  Dannemann Eriksen  2/14/1992   27
# 2            P. Pogba                        Paul Pogba  3/15/1993   25
# 3          L. Insigne                   Lorenzo Insigne   6/4/1991   27
# 4        K. Koulibaly                 Kalidou Koulibaly  6/20/1991   27
# ...               ...                               ...        ...  ...
# 17949     R. McKenzie                    Rory  McKenzie  10/7/1993   25
# 17950       M. Sipľak                     Michal Sipľak   2/2/1996   23
# 17951      J. Bekkema                       Jan Bekkema   4/9/1996   22
# 17952      A. Al Yami               Abdulrahman Al Yami  6/19/1997   21
# 17953  Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19
#
#        height_cm  weight_kgs  positions   nationality  overall_rating  \
# ...

# %%
player_agt=data['name']
player_agt
# Out:
# 0              L. Messi
# 1            C. Eriksen
# 2              P. Pogba
# 3            L. Insigne
# 4          K. Koulibaly
#               ...
# 17949       R. McKenzie
# 17950         M. Sipľak
# 17951        J. Bekkema
# 17952        A. Al Yami
# 17953    Júnior Brumado
# Name: name, Length: 17954, dtype: object

# %%
data.shape
# Out:
# (17954, 51)

# %%
dictionary=data.to_dict(orient='records')
dictionary
# Out:
# [{'name': 'L. Messi',
#   'full_name': 'Lionel Andrés Messi Cuccittini',
#   'birth_date': '6/24/1987',
#   'age': 31,
#   'height_cm': 170.18,
#   'weight_kgs': 72.1,
#   'positions': 'CF,RW,ST',
#   'nationality': 'Argentina',
#   'overall_rating': 94,
#   'potential': 94,
#   'value_euro': 110500000.0,
#   'wage_euro': 565000.0,
#   'preferred_foot': 'Left',
#   'international_reputation(1-5)': 5,
#   'weak_foot(1-5)': 4,
#   'skill_moves(1-5)': 4,
#   'body_type': 'Messi',
#   'release_clause_euro': 226500000.0,
#   'national_team': 'Argentina',
#   'national_rating': 82.0,
#   'national_team_position': 'RF',
#   'national_jersey_number': 10.0,
#   'crossing': 86,
#   'finishing': 95,
#   'heading_accuracy': 70,
#   'short_passing': 92,
#   'volleys': 86,
#   'dribbling': 97,
#   'curve': 93,
#   'freekick_accuracy': 94,
#   'long_passing': 89,
#   'ball_control': 96,
#   'acceleration': 91,
#   'sprint_speed': 86,
#   'agility': 93,
#   'reactions': 95,
#   'balance': 95,
# ...

# %%
players_prefered=[]
for data in dictionary:
    if data['nationality']=='Argentina':
       players_prefered.append(data['name'])
players_prefered
# Out:
# ['L. Messi',
#  'S. Agüero',
#  'P. Dybala',
#  'G. Higuaín',
#  'M. Icardi',
#  'G. Lo Celso',
#  'N. Gaitán',
#  'L. López',
#  'J. Mascherano',
#  'I. Marcone',
#  'D. Benedetto',
#  'E. Lavezzi',
#  'C. Izquierdoz',
#  'W. Benítez',
#  'L. Ocampos',
#  'J. Calleri',
#  'R. Palacio',
#  'D. Cvitanich',
#  'R. Civelli',
#  'A. Szymanowski',
#  'L. López',
#  'N. Blandi',
#  'F. Fernández',
#  'M. Moralez',
#  'M. Benítez',
#  'R. Funes Mori',
#  'G. Carrillo',
#  'A. Franco',
#  'I. Fernández',
#  'L. Zelarayán',
#  'L. Orbán',
#  'S. Romero',
#  'G. Ortíz',
#  'R. Rey',
#  'N. Spolli',
#  'A. Ruiz',
#  'R. Botta',
#  'I. Sosa',
#  'N. Acevedo',
#  'B. Fernández',
#  'J. Basanta',
#  'M. Urruti',
#  'L. Bustamante',
#  'R. Aliendro',
#  'S. Bertoli',
#  'J. Gandolfi',
#  'N. Navarro',
#  'A. Barboza',
#  'P. Barrientos',
#  'F. Rinaudo',
#  'G. Peruzzi',
#  'J. Foyth',
#  'V. Vada',
#  'L. Pisculichi',
#  'N. Pasquini',
#  'V. Aguilera',
#  'N. González',
#  'G. Núñez',
# ...

# %%
players_prefered=[]
for data in dictionary:
    if data['positions']=='CB':
       players_prefered.append(data['name'])
players_prefered
# Out:
# ['K. Koulibaly',
#  'V. van Dijk',
#  'M. Škriniar',
#  'J. Vertonghen',
#  'T. Alderweireld',
#  'N. Süle',
#  'J. Giménez',
#  'D. Sánchez',
#  'Felipe',
#  'A. Romagnoli',
#  'J. Tah',
#  'C. Lenglet',
#  'M. Nastasić',
#  'F. Balbuena',
#  'J. Mathieu',
#  'J. Matip',
#  'A. Mandi',
#  'J. Murillo',
#  'A. Granqvist',
#  'Dante',
#  'L. Perrin',
#  'Víctor Ruiz',
#  'P. Jones',
#  'G. Cahill',
#  'C. Izquierdoz',
#  'N. Maksimović',
#  'L. Dunk',
#  'C. Schindler',
#  'Pedro Mendes',
#  'M. Hinteregger',
#  'W. Boly',
#  'Álvaro',
#  'Hilton',
#  'G. Maripán',
#  'S. Cook',
#  'B. Mee',
#  'Jorge Meré',
#  'Diego Llorente',
#  'Wallace',
#  'S. Tasci',
#  'S. De Maio',
#  'R. Civelli',
#  'K. Papadopoulos',
#  'P. Jagielka',
#  'P. Jansson',
#  'B. Espinosa',
#  'I. Diop',
#  'Juanpe',
#  'D. Reyes',
#  'L. López',
#  'F. Fernández',
#  'F. Benković',
#  'I. Ordets',
#  'Vitor Hugo',
#  'J. Morel',
#  'Juli Freitinho',
#  'D. Heintz',
#  'A. Soumaoro',
#  'Raúl Navas',
# ...
