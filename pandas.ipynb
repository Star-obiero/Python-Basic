# %% [markdown]
# Using .map() to transform values

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path=r"C:\Users\Administrator\Downloads\Titanic-Dataset.csv"
titanic_df=pd.read_csv(file_path)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# Using .map() to transform values

# %%
pclass_mapping={
    '3':'least expensive',
    '2':'standard',
    '1':'most luxirious & expensive'
}
pclass_mapping
# Out:
# {'3': 'least expensive', '2': 'standard', '1': 'most luxirious & expensive'}

# %%
titanic_df['Pclass'].map(pclass_mapping)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 886    NaN
# 887    NaN
# 888    NaN
# 889    NaN
# 890    NaN
# Name: Pclass, Length: 891, dtype: object

# %%
titanic_df['Pclass']=titanic_df['Pclass'].map(pclass_mapping)
titanic_df['Pclass']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 886    NaN
# 887    NaN
# 888    NaN
# 889    NaN
# 890    NaN
# Name: Pclass, Length: 891, dtype: object

# %% [markdown]
# Passing in a function

# %%
def class_fare(fare):
          if fare>=12:
               return True
          else:
               return False

# %%
titanic_df['Fare'].map(class_fare)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886     True
# 887     True
# 888     True
# 889     True
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %% [markdown]
# Rather than changing lets creat a new column to hold this changes

# %%
titanic_df['farre_per_class']=titanic_df['Fare'].map(class_fare)
titanic_df['farre_per_class']
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886     True
# 887     True
# 888     True
# 889     True
# 890    False
# Name: farre_per_class, Length: 891, dtype: bool

# %%
titanic_df
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0    NaN
# 1              2         1    NaN
# 2              3         1    NaN
# 3              4         1    NaN
# 4              5         0    NaN
# ..           ...       ...    ...
# 886          887         0    NaN
# 887          888         1    NaN
# 888          889         0    NaN
# 889          890         1    NaN
# 890          891         0    NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Renaming columns

# %%
titanic_df.rename(columns={'SibSp':'Number of siblings/spouses'})
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0    NaN
# 1              2         1    NaN
# 2              3         1    NaN
# 3              4         1    NaN
# 4              5         0    NaN
# ..           ...       ...    ...
# 886          887         0    NaN
# 887          888         1    NaN
# 888          889         0    NaN
# 889          890         1    NaN
# 890          891         0    NaN
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
titanic_df
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0    NaN
# 1              2         1    NaN
# 2              3         1    NaN
# 3              4         1    NaN
# 4              5         0    NaN
# ..           ...       ...    ...
# 886          887         0    NaN
# 887          888         1    NaN
# 888          889         0    NaN
# 889          890         1    NaN
# 890          891         0    NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# If you want the change to stick

# %%
titanic_df.rename(columns={'SibSp':'Number of siblings/spouses'},inplace=True)

# %%
titanic_df
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0    NaN
# 1              2         1    NaN
# 2              3         1    NaN
# 3              4         1    NaN
# 4              5         0    NaN
# ..           ...       ...    ...
# 886          887         0    NaN
# 887          888         1    NaN
# 888          889         0    NaN
# 889          890         1    NaN
# 890          891         0    NaN
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %% [markdown]
# Dropping columns

# %%
titanic_df.drop('farre_per_class',axis=1)
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0    NaN
# 1              2         1    NaN
# 2              3         1    NaN
# 3              4         1    NaN
# 4              5         0    NaN
# ..           ...       ...    ...
# 886          887         0    NaN
# 887          888         1    NaN
# 888          889         0    NaN
# 889          890         1    NaN
# 890          891         0    NaN
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %% [markdown]
# changing column datatype

# %%
titanic_df['Fare'].dtype
# Out:
# dtype('float64')

# %%
titanic_df
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0    NaN
# 1              2         1    NaN
# 2              3         1    NaN
# 3              4         1    NaN
# 4              5         0    NaN
# ..           ...       ...    ...
# 886          887         0    NaN
# 887          888         1    NaN
# 888          889         0    NaN
# 889          890         1    NaN
# 890          891         0    NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PassengerId      891 non-null    int64
#  1   Survived         891 non-null    int64
#  2   Pclass           0 non-null      object
#  3   Name             891 non-null    object
#  4   Sex              891 non-null    object
#  5   Age              714 non-null    float64
#  6   SibSp            891 non-null    int64
#  7   Parch            891 non-null    int64
#  8   Ticket           891 non-null    object
#  9   Fare             891 non-null    float64
#  10  Cabin            204 non-null    object
#  11  Embarked         889 non-null    object
#  12  farre_per_class  891 non-null    bool
# dtypes: bool(1), float64(2), int64(4), object(6)
# memory usage: 84.5+ KB

# %%
titanic_df['SibSp']=titanic_df['SibSp'].astype(str)
