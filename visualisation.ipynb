# %% [markdown]
# Visualisation using seaborn and matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path=r"C:\Users\Administrator\Downloads\heart.csv"
heart_df=pd.read_csv(file_path)
heart_df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
heart_df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
new_sex={
    1:'Male',
    0:'Female'
}

# %%
heart_df['sex']=heart_df['sex'].map(new_sex)

# %%
new_cp={
    0:'Typical angina',
    1:'Antypical angina',
    2:'Non-aginal pain',
    3:'Assymptomatic'
}

# %%
heart_df['cp']=heart_df['cp'].map(new_cp)

# %%
new_fbs={
    0:'False',
    1:'True'
}

# %% [markdown]
# Fastin blood sugar>120mg/dl

# %%
heart_df['fbs']=heart_df['fbs'].map(new_fbs)

# %%
restecg_new={
    0:'Normal',
    1:'ST-Twave abnomality',
    3:'Left ventricular hypathropy',
}

# %%
heart_df['restecg']=heart_df['restecg'].map(restecg_new)

# %%
exang_new={
    1:'Yes',
    0:'No'
}

# %%
heart_df['exang']=heart_df['exang'].map(exang_new)

# %%
new_slope={
    0:'Upslope',
    1:'Flat',
    2:'Downsloping'
}

# %%
heart_df['slope']=heart_df['slope'].map(new_slope)

# %%
new_thal={
    1:'Normal',
    2:'Fixed defect',
    3:'Reversibel defect'
}

# %%
heart_df['thal']=heart_df['thal'].map(new_thal)

# %%
new_target={
    0:'No heart disease',
    1:'Heart disase present'
}

# %%
heart_df['target']=heart_df['target'].map(new_target)

# %%
heart_df
# Out:
#       age     sex                cp  trestbps  chol    fbs  \
# 0      52    Male    Typical angina       125   212  False
# 1      53    Male    Typical angina       140   203   True
# 2      70    Male    Typical angina       145   174  False
# 3      61    Male    Typical angina       148   203  False
# 4      62  Female    Typical angina       138   294   True
# ...   ...     ...               ...       ...   ...    ...
# 1020   59    Male  Antypical angina       140   221  False
# 1021   60    Male    Typical angina       125   258  False
# 1022   47    Male    Typical angina       110   275  False
# 1023   50  Female    Typical angina       110   254  False
# 1024   54    Male    Typical angina       120   188  False
#
#                   restecg  thalach exang  oldpeak        slope  ca  \
# 0     ST-Twave abnomality      168    No      1.0  Downsloping   2
# 1                  Normal      155   Yes      3.1      Upslope   0
# ...
